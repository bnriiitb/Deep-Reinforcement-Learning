# %% [markdown]
# # Continuous Control
#
# ---
#
# In this notebook, you will learn how to use the Unity ML-Agents environment for the second project of the [Deep Reinforcement Learning Nanodegree](https://www.udacity.com/course/deep-reinforcement-learning-nanodegree--nd893) program.
#
# ### 1. Start the Environment
#
# We begin by importing the necessary packages.  If the code cell below returns an error, please revisit the project instructions to double-check that you have installed [Unity ML-Agents](https://github.com/Unity-Technologies/ml-agents/blob/master/docs/Installation.md) and [NumPy](http://www.numpy.org/).

# %%
from unityagents import UnityEnvironment
import numpy as np
import torch
from collections import deque

import matplotlib.pyplot as plt
# %matplotlib inline

from ddpg_agent import Agent

# %% [markdown]
# Next, we will start the environment!  **_Before running the code cell below_**, change the `file_name` parameter to match the location of the Unity environment that you downloaded.
#
# - **Mac**: `"path/to/Reacher.app"`
# - **Windows** (x86): `"path/to/Reacher_Windows_x86/Reacher.exe"`
# - **Windows** (x86_64): `"path/to/Reacher_Windows_x86_64/Reacher.exe"`
# - **Linux** (x86): `"path/to/Reacher_Linux/Reacher.x86"`
# - **Linux** (x86_64): `"path/to/Reacher_Linux/Reacher.x86_64"`
# - **Linux** (x86, headless): `"path/to/Reacher_Linux_NoVis/Reacher.x86"`
# - **Linux** (x86_64, headless): `"path/to/Reacher_Linux_NoVis/Reacher.x86_64"`
#
# For instance, if you are using a Mac, then you downloaded `Reacher.app`.  If this file is in the same folder as the notebook, then the line below should appear as follows:
# ```
# env = UnityEnvironment(file_name="Reacher.app")
# ```

# %%
#20 agents
env = UnityEnvironment(file_name='Reacher_20.app', seed=2)
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
# 		goal_speed -> 1.0
# 		goal_size -> 5.0
# Unity brain name: ReacherBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 33
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %% [markdown]
# Environments contain **_brains_** which are responsible for deciding the actions of their associated agents. Here we check for the first brain available, and set it as the default brain we will be controlling from Python.

# %%
# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

# %% [markdown]
# ### 2. Examine the State and Action Spaces
#
# In this environment, a double-jointed arm can move to target locations. A reward of `+0.1` is provided for each step that the agent's hand is in the goal location. Thus, the goal of your agent is to maintain its position at the target location for as many time steps as possible.
#
# The observation space consists of `33` variables corresponding to position, rotation, velocity, and angular velocities of the arm.  Each action is a vector with four numbers, corresponding to torque applicable to two joints.  Every entry in the action vector must be a number between `-1` and `1`.
#
# The simulation contains `20` identical agents, each with its own copy of the environment.
#
# Run the code cell below to print some information about the environment.

# %%
# reset the environment
env_info = env.reset(train_mode=True)[brain_name]

# number of agents
num_agents = len(env_info.agents)
print('Number of agents:', num_agents)

# size of each action
action_size = brain.vector_action_space_size
print('Size of each action:', action_size)

# examine the state space 
states = env_info.vector_observations
state_size = states.shape[1]
print('There are {} agents. Each observes a state with length: {}'.format(states.shape[0], state_size))
print('The state for the first agent looks like:', states[0])
# Out:
# Number of agents: 20
# Size of each action: 4
# There are 20 agents. Each observes a state with length: 33
# The state for the first agent looks like: [ 0.00000000e+00 -4.00000000e+00  0.00000000e+00  1.00000000e+00
#  -0.00000000e+00 -0.00000000e+00 -4.37113883e-08  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -1.00000000e+01  0.00000000e+00
#   1.00000000e+00 -0.00000000e+00 -0.00000000e+00 -4.37113883e-08
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -1.39617920e-01 -1.00000000e+00
#  -7.99878311e+00  0.00000000e+00  1.00000000e+00  0.00000000e+00
#   8.00664425e-01]

# %% [markdown]
# ### 3. Take Random Actions in the Environment
#
# In the next code cell, you will learn how to use the Python API to control the agent and receive feedback from the environment.
#
# Once this cell is executed, you will watch the agent's performance, if it selects an action at random with each time step.  A window should pop up that allows you to observe the agent, as it moves through the environment.
#
# Of course, as part of the project, you'll have to change the code so that the agent is able to use its experience to gradually choose better actions when interacting with the environment!

# %%
env_info = env.reset(train_mode=False)[brain_name]     # reset the environment    
states = env_info.vector_observations                  # get the current state (for each agent)
scores = np.zeros(num_agents)

# %%
env_info = env.reset(train_mode=False)[brain_name]     # reset the environment    
states = env_info.vector_observations                  # get the current state (for each agent)
scores = np.zeros(num_agents)                          # initialize the score (for each agent)
while True:
    actions = np.random.randn(num_agents, action_size) # select an action (for each agent)
    actions = np.clip(actions, -1, 1)                  # all actions between -1 and 1
    env_info = env.step(actions)[brain_name]           # send all actions to tne environment
    next_states = env_info.vector_observations         # get next state (for each agent)
    rewards = env_info.rewards                         # get reward (for each agent)
    dones = env_info.local_done                        # see if episode finished
    scores += env_info.rewards                         # update the score (for each agent)
    states = next_states                               # roll over states to next time step
    if np.any(dones):                                  # exit loop if episode finished
        break
print('Total score (averaged over agents) this episode: {}'.format(np.mean(scores)))

# %% [markdown]
# When finished, you can close the environment.

# %% [markdown]
# #agent = Agent(state_size=state_size, action_size=action_size, random_seed=2)

# %% [markdown]
# ### 4. It's Your Turn!
#
# Now it's your turn to train your own agent to solve the environment!  When training the environment, set `train_mode=True`, so that the line for resetting the environment looks like the following:
# ```python
# env_info = env.reset(train_mode=True)[brain_name]
# ```

# %%
def DDPG(n_episodes=300, max_t=500):
    avg_score = []
    scores_deque = deque(maxlen=100)
    scores = np.zeros(num_agents)
    time_steps = 20
    update = 10
    
    solved = False
    env_info = env.reset(train_mode=True)[brain_name]
    
    states = env_info.vector_observations
    
    agent_tuple = {"state_size": state_size, "action_size": action_size, "random_seed": 2,}
    agents = [Agent(**agent_tuple) for _ in range(num_agents)]
    action = [agent.act(states[i]) for i, agent in enumerate(agents)]   
    
    for i_episode in range(1, n_episodes+1):
        states = env_info.vector_observations                 
        for agent in agents:
            agent.reset()

        for t in range(max_t):
            actions = [agent.act(states[i]) for i, agent in enumerate(agents)]            
            env_info = env.step(actions)[brain_name]
            next_states = env_info.vector_observations         
            rewards = env_info.rewards                         
            dones = env_info.local_done                       
            
            step_t = zip(agents, states, actions, rewards, next_states, dones)
            
            for agent, state, action, reward, next_step, done in step_t:
                agent.memory.add(state, action, reward, next_step, done)
                if ( t % time_steps == 0):
                    agent.step(state, action, reward, next_step, done, update)
            states  = next_states
            scores += rewards                                  
            if np.any(dones):                                 
                break
                
        score = np.mean(scores)        
        avg_score.append(score)
        scores_deque.append(score)
        avg = np.mean(scores_deque)            
            
        print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, avg,), end="\n")

        if not solved and np.mean(scores_deque) > 30.:
            print("\r\rEnviroment solved in @ i_episode={i_episode}, w/ avg_score={avg:.2f}\r".format(i_episode=i_episode, avg=avg))
            solved= True

    torch.save(agent.actor_local.state_dict(), 'checkpoint_actor.pth')
    torch.save(agent.critic_local.state_dict(), 'checkpoint_critic.pth')
    
    return avg_score

# %%
scores = DDPG()
# Out:
# Episode 1	Average Score: 0.18
# Episode 2	Average Score: 0.30
# Episode 3	Average Score: 0.34
# Episode 4	Average Score: 0.43
# Episode 5	Average Score: 0.50
# Episode 6	Average Score: 0.55
# Episode 7	Average Score: 0.60
# Episode 8	Average Score: 0.65
# Episode 9	Average Score: 0.68
# Episode 10	Average Score: 0.71
# Episode 11	Average Score: 0.74
# Episode 12	Average Score: 0.76
# Episode 13	Average Score: 0.79
# Episode 14	Average Score: 0.82
# Episode 15	Average Score: 0.84
# Episode 16	Average Score: 0.86
# Episode 17	Average Score: 0.88
# Episode 18	Average Score: 0.90
# Episode 19	Average Score: 0.92
# Episode 20	Average Score: 0.94
# Episode 21	Average Score: 0.96
# Episode 22	Average Score: 0.98
# Episode 23	Average Score: 1.00
# Episode 24	Average Score: 1.02
# Episode 25	Average Score: 1.04
# Episode 26	Average Score: 1.07
# Episode 27	Average Score: 1.09
# Episode 28	Average Score: 1.11
# Episode 29	Average Score: 1.13
# Episode 30	Average Score: 1.15
# Episode 31	Average Score: 1.17
# Episode 32	Average Score: 1.19
# Episode 33	Average Score: 1.21
# Episode 34	Average Score: 1.23
# Episode 35	Average Score: 1.25
# Episode 36	Average Score: 1.27
# Episode 37	Average Score: 1.30
# Episode 38	Average Score: 1.32
# Episode 39	Average Score: 1.34
# Episode 40	Average Score: 1.37
# Episode 41	Average Score: 1.40
# Episode 42	Average Score: 1.42
# Episode 43	Average Score: 1.45
# Episode 44	Average Score: 1.48
# Episode 45	Average Score: 1.51
# Episode 46	Average Score: 1.54
# Episode 47	Average Score: 1.57
# Episode 48	Average Score: 1.60
# Episode 49	Average Score: 1.63
# Episode 50	Average Score: 1.67
# Episode 51	Average Score: 1.70
# Episode 52	Average Score: 1.73
# Episode 53	Average Score: 1.77
# Episode 54	Average Score: 1.80
# Episode 55	Average Score: 1.84
# Episode 56	Average Score: 1.88
# Episode 57	Average Score: 1.92
# Episode 58	Average Score: 1.96
# Episode 59	Average Score: 2.00
# Episode 60	Average Score: 2.04
# Episode 61	Average Score: 2.08
# Episode 62	Average Score: 2.13
# Episode 63	Average Score: 2.17
# Episode 64	Average Score: 2.21
# Episode 65	Average Score: 2.26
# Episode 66	Average Score: 2.30
# Episode 67	Average Score: 2.35
# Episode 68	Average Score: 2.40
# Episode 69	Average Score: 2.44
# Episode 70	Average Score: 2.49
# Episode 71	Average Score: 2.54
# Episode 72	Average Score: 2.58
# Episode 73	Average Score: 2.63
# Episode 74	Average Score: 2.68
# Episode 75	Average Score: 2.73
# Episode 76	Average Score: 2.78
# Episode 77	Average Score: 2.83
# Episode 78	Average Score: 2.88
# Episode 79	Average Score: 2.93
# Episode 80	Average Score: 2.98
# Episode 81	Average Score: 3.03
# Episode 82	Average Score: 3.08
# Episode 83	Average Score: 3.14
# Episode 84	Average Score: 3.19
# Episode 85	Average Score: 3.24
# Episode 86	Average Score: 3.30
# Episode 87	Average Score: 3.35
# Episode 88	Average Score: 3.41
# Episode 89	Average Score: 3.46
# Episode 90	Average Score: 3.52
# Episode 91	Average Score: 3.57
# Episode 92	Average Score: 3.63
# Episode 93	Average Score: 3.69
# Episode 94	Average Score: 3.75
# Episode 95	Average Score: 3.81
# Episode 96	Average Score: 3.86
# Episode 97	Average Score: 3.92
# Episode 98	Average Score: 3.98
# Episode 99	Average Score: 4.04
# Episode 100	Average Score: 4.10
# Episode 101	Average Score: 4.21
# Episode 102	Average Score: 4.31
# Episode 103	Average Score: 4.41
# Episode 104	Average Score: 4.52
# Episode 105	Average Score: 4.62
# Episode 106	Average Score: 4.72
# Episode 107	Average Score: 4.83
# Episode 108	Average Score: 4.93
# Episode 109	Average Score: 5.04
# Episode 110	Average Score: 5.16
# Episode 111	Average Score: 5.27
# Episode 112	Average Score: 5.38
# Episode 113	Average Score: 5.50
# Episode 114	Average Score: 5.62
# Episode 115	Average Score: 5.74
# Episode 116	Average Score: 5.86
# Episode 117	Average Score: 5.99
# Episode 118	Average Score: 6.11
# Episode 119	Average Score: 6.24
# Episode 120	Average Score: 6.37
# Episode 121	Average Score: 6.50
# Episode 122	Average Score: 6.64
# Episode 123	Average Score: 6.77
# Episode 124	Average Score: 6.91
# Episode 125	Average Score: 7.04
# Episode 126	Average Score: 7.18
# Episode 127	Average Score: 7.33
# Episode 128	Average Score: 7.47
# Episode 129	Average Score: 7.62
# Episode 130	Average Score: 7.77
# Episode 131	Average Score: 7.92
# Episode 132	Average Score: 8.07
# Episode 133	Average Score: 8.23
# Episode 134	Average Score: 8.39
# Episode 135	Average Score: 8.54
# Episode 136	Average Score: 8.70
# Episode 137	Average Score: 8.87
# Episode 138	Average Score: 9.03
# Episode 139	Average Score: 9.19
# Episode 140	Average Score: 9.36
# Episode 141	Average Score: 9.53
# Episode 142	Average Score: 9.70
# Episode 143	Average Score: 9.87
# Episode 144	Average Score: 10.04
# Episode 145	Average Score: 10.22
# Episode 146	Average Score: 10.39
# Episode 147	Average Score: 10.57
# Episode 148	Average Score: 10.75
# Episode 149	Average Score: 10.93
# Episode 150	Average Score: 11.11
# Episode 151	Average Score: 11.30
# Episode 152	Average Score: 11.48
# Episode 153	Average Score: 11.67
# Episode 154	Average Score: 11.85
# Episode 155	Average Score: 12.04
# Episode 156	Average Score: 12.23
# Episode 157	Average Score: 12.42
# Episode 158	Average Score: 12.62
# Episode 159	Average Score: 12.81
# Episode 160	Average Score: 13.01
# Episode 161	Average Score: 13.21
# Episode 162	Average Score: 13.41
# Episode 163	Average Score: 13.62
# Episode 164	Average Score: 13.82
# Episode 165	Average Score: 14.02
# Episode 166	Average Score: 14.23
# Episode 167	Average Score: 14.44
# Episode 168	Average Score: 14.65
# Episode 169	Average Score: 14.86
# Episode 170	Average Score: 15.08
# Episode 171	Average Score: 15.29
# Episode 172	Average Score: 15.51
# Episode 173	Average Score: 15.74
# Episode 174	Average Score: 15.96
# Episode 175	Average Score: 16.18
# Episode 176	Average Score: 16.41
# Episode 177	Average Score: 16.63
# Episode 178	Average Score: 16.86
# Episode 179	Average Score: 17.10
# Episode 180	Average Score: 17.33
# Episode 181	Average Score: 17.57
# Episode 182	Average Score: 17.81
# Episode 183	Average Score: 18.05
# Episode 184	Average Score: 18.29
# Episode 185	Average Score: 18.53
# Episode 186	Average Score: 18.78
# Episode 187	Average Score: 19.03
# Episode 188	Average Score: 19.28
# Episode 189	Average Score: 19.53
# Episode 190	Average Score: 19.78
# Episode 191	Average Score: 20.03
# Episode 192	Average Score: 20.29
# Episode 193	Average Score: 20.54
# Episode 194	Average Score: 20.80
# Episode 195	Average Score: 21.06
# Episode 196	Average Score: 21.31
# Episode 197	Average Score: 21.58
# Episode 198	Average Score: 21.83
# Episode 199	Average Score: 22.09
# Episode 200	Average Score: 22.36
# Episode 201	Average Score: 22.62
# Episode 202	Average Score: 22.89
# Episode 203	Average Score: 23.16
# Episode 204	Average Score: 23.42
# Episode 205	Average Score: 23.69
# Episode 206	Average Score: 23.96
# Episode 207	Average Score: 24.23
# Episode 208	Average Score: 24.50
# Episode 209	Average Score: 24.77
# Episode 210	Average Score: 25.04
# Episode 211	Average Score: 25.32
# Episode 212	Average Score: 25.59
# Episode 213	Average Score: 25.87
# Episode 214	Average Score: 26.15
# Episode 215	Average Score: 26.43
# Episode 216	Average Score: 26.70
# Episode 217	Average Score: 26.99
# Episode 218	Average Score: 27.27
# Episode 219	Average Score: 27.56
# Episode 220	Average Score: 27.84
# Episode 221	Average Score: 28.13
# Episode 222	Average Score: 28.42
# Episode 223	Average Score: 28.71
# Episode 224	Average Score: 29.00
# Episode 225	Average Score: 29.29
# Episode 226	Average Score: 29.58
# Episode 227	Average Score: 29.88
# Episode 228	Average Score: 30.17
# Enviroment solved in @ i_episode=228, w/ avg_score=30.17
# Episode 229	Average Score: 30.46
# Episode 230	Average Score: 30.76
# Episode 231	Average Score: 31.06
# Episode 232	Average Score: 31.36
# Episode 233	Average Score: 31.66
# Episode 234	Average Score: 31.95
# Episode 235	Average Score: 32.26
# Episode 236	Average Score: 32.56
# Episode 237	Average Score: 32.86
# Episode 238	Average Score: 33.17
# Episode 239	Average Score: 33.47
# Episode 240	Average Score: 33.77
# Episode 241	Average Score: 34.08
# Episode 242	Average Score: 34.39
# Episode 243	Average Score: 34.69
# Episode 244	Average Score: 35.00
# Episode 245	Average Score: 35.31
# Episode 246	Average Score: 35.62
# Episode 247	Average Score: 35.93
# Episode 248	Average Score: 36.24
# Episode 249	Average Score: 36.55
# Episode 250	Average Score: 36.86
# Episode 251	Average Score: 37.17
# Episode 252	Average Score: 37.48
# Episode 253	Average Score: 37.79
# Episode 254	Average Score: 38.11
# Episode 255	Average Score: 38.42
# Episode 256	Average Score: 38.74
# Episode 257	Average Score: 39.05
# Episode 258	Average Score: 39.37
# Episode 259	Average Score: 39.68
# Episode 260	Average Score: 40.00
# Episode 261	Average Score: 40.31
# Episode 262	Average Score: 40.63
# Episode 263	Average Score: 40.94
# Episode 264	Average Score: 41.26
# Episode 265	Average Score: 41.58
# Episode 266	Average Score: 41.89
# Episode 267	Average Score: 42.21
# Episode 268	Average Score: 42.53
# Episode 269	Average Score: 42.84
# Episode 270	Average Score: 43.16
# Episode 271	Average Score: 43.48
# Episode 272	Average Score: 43.80
# Episode 273	Average Score: 44.11
# Episode 274	Average Score: 44.43
# Episode 275	Average Score: 44.75
# Episode 276	Average Score: 45.07
# Episode 277	Average Score: 45.39
# Episode 278	Average Score: 45.70
# Episode 279	Average Score: 46.02
# Episode 280	Average Score: 46.34
# Episode 281	Average Score: 46.66
# Episode 282	Average Score: 46.97
# Episode 283	Average Score: 47.29
# Episode 284	Average Score: 47.60
# Episode 285	Average Score: 47.92
# Episode 286	Average Score: 48.23
# Episode 287	Average Score: 48.54
# Episode 288	Average Score: 48.85
# Episode 289	Average Score: 49.17
# Episode 290	Average Score: 49.48
# Episode 291	Average Score: 49.80
# Episode 292	Average Score: 50.11
# Episode 293	Average Score: 50.43
# Episode 294	Average Score: 50.74
# Episode 295	Average Score: 51.05
# Episode 296	Average Score: 51.37
# Episode 297	Average Score: 51.69
# Episode 298	Average Score: 52.00
# Episode 299	Average Score: 52.32
# Episode 300	Average Score: 52.63

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(scores)+1), scores)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.show()

# %%
env.close()
